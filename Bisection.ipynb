# %%
import numpy as np 
import matplotlib.pyplot as plt 
import math

# %%
x=np.linspace(-5,5,500)
y=(x*x*x)-(3*x)+1

# %%
plt.figure(figsize=(10,10))
plt.axhline(0,color='black')
plt.axvline(0,color='black')
plt.plot(x,y,label="y = x³ - 3x + 1")
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %%
# eq=X^3 -3x+1
def  equation(x):
    y=pow(x,3)-(3*x)+1
    return y

# %%
print(equation(0.5))
# Out:
# -0.375

# %%
a,b=map(int,input().split())

# %%
print(a,b)
print(type(a))
# Out:
# 0 1
# <class 'int'>

# %%
x=equation(a)*equation(b)

# %%
if(x>0):
    print('does not exist solution')
else:
    print('There exist at least one valid solution')
# Out:
# There exist at least one valid solution

# %%
if(equation(a)>=0):
    c=a
    a=b
    b=c

# %%
def error(z):
    if(z<0):
        z=-z
    return z*100

# %%
thressh=0.0000001
iteration =1000
z=0
for i in range(iteration):
    z=(a+b)/2
    fz=equation(z)
    if(abs(fz)<=thressh):
        break;
    
    elif(fz>=0):
        b=z
    else:
        a=z
    print(z,f"Error={error(fz)}%")
print(f"Solution is nearly at {z}")
# Out:
# 0.5 Error=37.5%
# 0.25 Error=26.5625%
# 0.375 Error=7.2265625%
# 0.3125 Error=9.3017578125%
# 0.34375 Error=0.9368896484375%
# 0.359375 Error=3.1711578369140625%
# 0.3515625 Error=1.1235713958740234%
# 0.34765625 Error=0.09493231773376465%
# 0.345703125 Error=0.420583039522171%
# 0.3466796875 Error=0.16272617504000664%
# 0.34716796875 Error=0.03387209726497531%
# 0.347412109375 Error=0.03053632244700566%
# 0.3472900390625 Error=0.0016663349015288986%
# 0.34735107421875 Error=0.014435381967814465%
# 0.347320556640625 Error=0.006384620573385291%
# 0.3473052978515625 Error=0.0023591670949230092%
# 0.34729766845703125 Error=0.0003464221613125318%
# 0.3472938537597656 Error=0.0006599548539654165%
# 0.34729576110839844 Error=0.00015676596729630177%
# 0.34729671478271484 Error=9.482819176565016e-05%
# 0.34729623794555664 Error=3.096886407316646e-05%
# 0.34729647636413574 Error=3.19296697748328e-05%
# Solution is nearly at 0.3472963571548462
